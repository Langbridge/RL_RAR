# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['figure.figsize'] = (15,8)

FILEPATH = {
    # '/Users/abilangbridge/Downloads/PPO_simple_ba65f_00000_0_2023-03-08_20-42-23/': '1 agent train',
    # '/Users/abilangbridge/Downloads/PPO_simple_445bb_00000_0_2023-03-10_19-03-39/': '10 agent train',
    # '/Users/abilangbridge/Downloads/PPO_simple_0af5b_00000_0_2023-03-13_01-40-32/': '1,000 agent train',
    # '/Users/abilangbridge/Downloads/PPO_simple_9d200_00000_0_2023-03-18_16-43-23/': '10 agent train (small hills)',
    # '/Users/abilangbridge/Downloads/PPO_simple_44a90_00000_0_2023-03-27_11-58-12/': '10 agent train (no vel) (hills)',
    '/Users/al4518/ray_results/PPO/PPO_simple_fa70e_00000_0_2023-03-27_22-40-23/': '10 agent train (no vel) (hills & corners)',
    '/Users/al4518/ray_results/PPO/PPO_simple_7cb39_00000_0_2023-03-28_16-16-17/': '10 agent train (no vel) (hills) (change gamma)',
    '/Users/al4518/ray_results/PPO/PPO_simple_1147d_00000_0_2023-03-29_19-03-54/': '10 agent train (no vel) (hills & staged goals) (change gamma)',
    '/Users/al4518/Downloads/PPO_simple_56013_00000_0_2023-03-29_10-44-44/': '10 agent train (no vel) (hills) (aggressive gamma)',
}

# %%
for path, alias in FILEPATH.items():
    df = pd.read_csv(f'{path}progress.csv')
    
    fig = plt.figure()
    ax = plt.gca()
    plt.title(f'{alias} Reward Convergence')
    df.plot(kind='scatter', x='training_iteration', y='episode_reward_mean', ax=ax)

# %%
for path, alias in FILEPATH.items():
    df = pd.read_csv(f'{path}progress.csv')
    
    fig = plt.figure()
    ax = plt.gca()
    plt.title(f'{alias} Reward Convergence')
    df.plot(kind='scatter', x='training_iteration', y='episode_len_mean', ax=ax)
